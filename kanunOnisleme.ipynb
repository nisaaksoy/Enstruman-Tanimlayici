# %%
import os
from pydub import AudioSegment, silence
import librosa
import numpy as np
import noisereduce as nr

# Klasör yolları
input_folder = "kanun_sarkilari"  # İndirilen şarkılar burada
output_folder = "temizlenmis_parcalarKanun"  # Çıktılar buraya kaydedilecek
mfcc_folder = "mfcc_cikti_kanun"  # MFCC çıktılarını kaydedecek klasör

# Klasörleri oluştur (varsa hata vermez)
os.makedirs(output_folder, exist_ok=True)
os.makedirs(mfcc_folder, exist_ok=True)

# Sessizlik Temizleme Fonksiyonu
def remove_silence(audio_file, silence_thresh=-50, min_silence_len=500):
    """Verilen MP3 dosyasından sessiz bölümleri kaldırır."""
    audio = AudioSegment.from_mp3(audio_file)
    non_silent_chunks = silence.detect_nonsilent(audio, min_silence_len, silence_thresh)
    cleaned_audio = sum([audio[start:end] for start, end in non_silent_chunks])
    return cleaned_audio

# Gürültü Temizleme ve Normalizasyon Fonksiyonu
def process_audio(y, sr):
    # Gürültü Temizleme
    y_denoised = nr.reduce_noise(y=y, sr=sr)
    # Normalizasyon
    y_normalized = librosa.util.normalize(y_denoised)
    return y_normalized

# MFCC Çıkarma Fonksiyonu
def extract_mfcc(y, sr, n_mfcc=13):
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return mfccs

# Şarkıları Parçalara Ayırma Fonksiyonu
def split_audio(audio, file_name, output_folder, segment_duration=3):
    """AudioSegment nesnesini segmentlere ayırır ve her segment için işlemler yapar."""
    total_duration = len(audio) / 1000  # milisaniyeden saniyeye

    segment_paths = []  # Segment dosyalarının yollarını saklamak için

    for i in range(0, int(total_duration), segment_duration):
        segment = audio[i * 1000: (i + segment_duration) * 1000]
        
        # Segmenti geçici bir dosyaya kaydet
        segment_path = os.path.join(output_folder, f"{file_name}_segment_{i}.wav")
        segment.export(segment_path, format="wav")
        print(f"{segment_path} kaydedildi.")
        
        # Gürültü temizleme, normalizasyon ve MFCC çıkarma işlemleri
        y, sr = librosa.load(segment_path, sr=None)
        y_processed = process_audio(y, sr)
        mfcc_features = extract_mfcc(y_processed, sr)

        # MFCC sonuçlarını kaydet
        mfcc_file = os.path.join(mfcc_folder, f"{file_name}_segment_{i}_mfcc.npy")
        np.save(mfcc_file, mfcc_features)
        print(f"{mfcc_file} MFCC özellikleri kaydedildi.")

        segment_paths.append(segment_path)  # Segment yolunu sakla

    return segment_paths  # Segment yollarını döndür

# Tüm şarkılar için işlemleri uygula
for file_name in os.listdir(input_folder):
    if file_name.endswith(".mp3"):
        file_path = os.path.join(input_folder, file_name)
        
        # Sessizliği Temizle
        print(f"{file_name} için sessizlik temizleniyor...")
        cleaned_audio = remove_silence(file_path)

        # Parçalara Ayır ve İşle
        print(f"{file_name} parçalara ayrılıyor ve işleniyor...")
        split_audio(cleaned_audio, file_name, output_folder, segment_duration=3)

print("Tüm şarkılar başarıyla işlendi.")

# Dosya adlarını yeniden adlandır
print("Dosya isimleri yeniden adlandırılıyor...")
if os.path.isdir(output_folder):
    wav_dosyalari = [dosya for dosya in os.listdir(output_folder) if dosya.endswith(".wav")]
    for i, dosya in enumerate(wav_dosyalari):
        yeni_dosya_adi = f"kanun_{i + 1}.wav"
wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_132.wav -> kanun_3064.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_135.wav -> kanun_3065.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_138.wav -> kanun_3066.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_141.wav -> kanun_3067.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_144.wav -> kanun_3068.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_147.wav -> kanun_3069.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_15.wav -> kanun_3070.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_150.wav -> kanun_3071.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_153.wav -> kanun_3072.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_156.wav -> kanun_3073.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_159.wav -> kanun_3074.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_162.wav -> kanun_3075.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_165.wav -> kanun_3076.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_168.wav -> kanun_3077.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_171.wav -> kanun_3078.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_174.wav -> kanun_3079.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_177.wav -> kanun_3080.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_18.wav -> kanun_3081.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_180.wav -> kanun_3082.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_183.wav -> kanun_3083.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_186.wav -> kanun_3084.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_189.wav -> kanun_3085.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_192.wav -> kanun_3086.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_195.wav -> kanun_3087.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_198.wav -> kanun_3088.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_201.wav -> kanun_3089.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_204.wav -> kanun_3090.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_207.wav -> kanun_3091.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_21.wav -> kanun_3092.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_210.wav -> kanun_3093.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_213.wav -> kanun_3094.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_216.wav -> kanun_3095.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_219.wav -> kanun_3096.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_222.wav -> kanun_3097.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_225.wav -> kanun_3098.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_228.wav -> kanun_3099.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_231.wav -> kanun_3100.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_234.wav -> kanun_3101.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_237.wav -> kanun_3102.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_24.wav -> kanun_3103.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_240.wav -> kanun_3104.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_243.wav -> kanun_3105.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_246.wav -> kanun_3106.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_249.wav -> kanun_3107.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_252.wav -> kanun_3108.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_255.wav -> kanun_3109.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_258.wav -> kanun_3110.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_261.wav -> kanun_3111.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_264.wav -> kanun_3112.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_267.wav -> kanun_3113.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_27.wav -> kanun_3114.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_270.wav -> kanun_3115.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_273.wav -> kanun_3116.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_276.wav -> kanun_3117.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_279.wav -> kanun_3118.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_282.wav -> kanun_3119.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_285.wav -> kanun_3120.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_288.wav -> kanun_3121.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_291.wav -> kanun_3122.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_294.wav -> kanun_3123.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_297.wav -> kanun_3124.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_3.wav -> kanun_3125.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_30.wav -> kanun_3126.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_300.wav -> kanun_3127.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_303.wav -> kanun_3128.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_306.wav -> kanun_3129.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_309.wav -> kanun_3130.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_312.wav -> kanun_3131.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_315.wav -> kanun_3132.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_318.wav -> kanun_3133.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_321.wav -> kanun_3134.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_324.wav -> kanun_3135.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_327.wav -> kanun_3136.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_33.wav -> kanun_3137.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_330.wav -> kanun_3138.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_333.wav -> kanun_3139.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_36.wav -> kanun_3140.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_39.wav -> kanun_3141.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_42.wav -> kanun_3142.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_45.wav -> kanun_3143.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_48.wav -> kanun_3144.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_51.wav -> kanun_3145.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_54.wav -> kanun_3146.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_57.wav -> kanun_3147.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_6.wav -> kanun_3148.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_60.wav -> kanun_3149.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_63.wav -> kanun_3150.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_66.wav -> kanun_3151.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_69.wav -> kanun_3152.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_72.wav -> kanun_3153.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_75.wav -> kanun_3154.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_78.wav -> kanun_3155.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_81.wav -> kanun_3156.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_84.wav -> kanun_3157.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_87.wav -> kanun_3158.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_9.wav -> kanun_3159.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_90.wav -> kanun_3160.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_93.wav -> kanun_3161.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_96.wav -> kanun_3162.wav olarak yeniden adlandırıldı.
# Yalnızım Dostlarım (Live).mp3_segment_99.wav -> kanun_3163.wav olarak yeniden adlandırıldı.
