# %%
import os
from pydub import AudioSegment, silence
import librosa
import numpy as np
import noisereduce as nr

# Klasör yolları
input_folder = "keman_sarkilari"  # İndirilen şarkılar burada
output_folder = "temizlenmis_parcalarKeman"  # Çıktılar buraya kaydedilecek
mfcc_folder = "mfcc_cikti_keman"  # MFCC çıktılarını kaydedecek klasör

# Klasörleri oluştur (varsa hata vermez)
os.makedirs(output_folder, exist_ok=True)
os.makedirs(mfcc_folder, exist_ok=True)

# Sessizlik Temizleme Fonksiyonu
def remove_silence(audio_file, silence_thresh=-50, min_silence_len=500):
    """Verilen MP3 dosyasından sessiz bölümleri kaldırır."""
    audio = AudioSegment.from_mp3(audio_file)
    non_silent_chunks = silence.detect_nonsilent(audio, min_silence_len, silence_thresh)
    cleaned_audio = sum([audio[start:end] for start, end in non_silent_chunks])
    return cleaned_audio

# Gürültü Temizleme ve Normalizasyon Fonksiyonu
def process_audio(y, sr):
    # Gürültü Temizleme
    y_denoised = nr.reduce_noise(y=y, sr=sr)
    # Normalizasyon
    y_normalized = librosa.util.normalize(y_denoised)
    return y_normalized

# MFCC Çıkarma Fonksiyonu
def extract_mfcc(y, sr, n_mfcc=13):
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return mfccs

# Şarkıları Parçalara Ayırma Fonksiyonu
def split_audio(audio, file_name, output_folder, segment_duration=3):
    """AudioSegment nesnesini segmentlere ayırır ve her segment için işlemler yapar."""
    total_duration = len(audio) / 1000  # milisaniyeden saniyeye

    segment_paths = []  # Segment dosyalarının yollarını saklamak için

    for i in range(0, int(total_duration), segment_duration):
        segment = audio[i * 1000: (i + segment_duration) * 1000]
        
        # Segmenti geçici bir dosyaya kaydet
        segment_path = os.path.join(output_folder, f"{file_name}_segment_{i}.wav")
        segment.export(segment_path, format="wav")
        print(f"{segment_path} kaydedildi.")
        
        # Gürültü temizleme, normalizasyon ve MFCC çıkarma işlemleri
        y, sr = librosa.load(segment_path, sr=None)
        y_processed = process_audio(y, sr)
        mfcc_features = extract_mfcc(y_processed, sr)

        # MFCC sonuçlarını kaydet
        mfcc_file = os.path.join(mfcc_folder, f"{file_name}_segment_{i}_mfcc.npy")
        np.save(mfcc_file, mfcc_features)
        print(f"{mfcc_file} MFCC özellikleri kaydedildi.")

        segment_paths.append(segment_path)  # Segment yolunu sakla

    return segment_paths  # Segment yollarını döndür

# Tüm şarkılar için işlemleri uygula
for file_name in os.listdir(input_folder):
    if file_name.endswith(".mp3"):
        file_path = os.path.join(input_folder, file_name)
        
        # Sessizliği Temizle
        print(f"{file_name} için sessizlik temizleniyor...")
        cleaned_audio = remove_silence(file_path)

        # Parçalara Ayır ve İşle
        print(f"{file_name} parçalara ayrılıyor ve işleniyor...")
        split_audio(cleaned_audio, file_name, output_folder, segment_duration=3)

print("Tüm şarkılar başarıyla işlendi.")

# Dosya adlarını yeniden adlandır
print("Dosya isimleri yeniden adlandırılıyor...")
if os.path.isdir(output_folder):
    wav_dosyalari = [dosya for dosya in os.listdir(output_folder) if dosya.endswith(".wav")]
    for i, dosya in enumerate(wav_dosyalari):
        yeni_dosya_adi = f"keman_{i + 1}.wav"
        eski_dosya_yolu = os.path.join(output_folder, dosya)
        yeni_dosya_yolu = os.path.join(output_folder, yeni_dosya_adi)

        try:
            # Dosyayı yeniden adlandır
            os.rename(eski_dosya_yolu, yeni_dosya_yolu)
            print(f"{dosya} -> {yeni_dosya_adi} olarak yeniden adlandırıldı.")
        except Exception as e:
            print(f"Dosya adlandırılırken hata oluştu: {e}")
else:
    print("Belirtilen klasör bulunamadı.")
# Out:
# 9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3 için sessizlik temizleniyor...
# 9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_0.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_3.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_6.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_9.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_12.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_15.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_18.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_21.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_24.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_27.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_30.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_33.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_36.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_39.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_42.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_45.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_48.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_51.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_54.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_57.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_60.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_63.wav kaydedildi.
# mfcc_cikti_keman\9. Senfoni ( Ode to Joy ) - Keman ( Violin ) Cover.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# Al Yazmalım - Keman ( Violin ) Cover.mp3 için sessizlik temizleniyor...
# Al Yazmalım - Keman ( Violin ) Cover.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_0.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_3.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_6.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_9.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_12.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_15.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_18.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_21.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_24.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_27.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_30.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_33.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_36.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_39.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_42.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_45.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_48.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_51.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_54.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_57.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_60.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_63.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_66.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_69.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_72.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_75.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_78.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_81.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_84.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_87.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_90.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_93.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_96.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_99.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_102.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_105.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_108.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_111.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_114.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_117.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_120.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_123.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_126.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_129.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_132.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_135.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_138.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_141.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_144.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_147.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_150.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_153.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_153_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_156.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_156_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_159.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_159_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_162.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_162_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_165.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_165_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_168.wav kaydedildi.
# mfcc_cikti_keman\Al Yazmalım - Keman ( Violin ) Cover.mp3_segment_168_mfcc.npy MFCC özellikleri kaydedildi.
# Ali Cabbar ｜ Keman Cover.mp3 için sessizlik temizleniyor...
# Ali Cabbar ｜ Keman Cover.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_0.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_3.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_6.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_9.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_12.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_15.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_18.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_21.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_24.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_27.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_30.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_33.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_36.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_39.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_42.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_45.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_48.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_51.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_54.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_57.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_60.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_63.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_66.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_69.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_72.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_75.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_78.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_81.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_84.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_87.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_90.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_93.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_96.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_99.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_102.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_105.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_108.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_111.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_114.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_117.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_120.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_123.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_126.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_129.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_132.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_135.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_138.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_141.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_144.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_147.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_150.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_153.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_153_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_156.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_156_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_159.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_159_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_162.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_162_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_165.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_165_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_168.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_168_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_171.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_171_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_174.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_174_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_177.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_177_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_180.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_180_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_183.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_183_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ali Cabbar ｜ Keman Cover.mp3_segment_186.wav kaydedildi.
# mfcc_cikti_keman\Ali Cabbar ｜ Keman Cover.mp3_segment_186_mfcc.npy MFCC özellikleri kaydedildi.
# Arkadaşım eşek - keman cover.mp3 için sessizlik temizleniyor...
# Arkadaşım eşek - keman cover.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_0.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_3.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_6.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_9.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_12.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_15.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_18.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_21.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_24.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_27.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_30.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_33.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_36.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_39.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_42.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_45.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_48.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_51.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_54.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_57.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_60.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_63.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_66.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_69.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_72.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_75.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_78.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_81.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_84.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_87.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_90.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_93.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_96.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_99.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_102.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_105.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_108.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_111.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_114.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_117.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_120.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Arkadaşım eşek - keman cover.mp3_segment_123.wav kaydedildi.
# mfcc_cikti_keman\Arkadaşım eşek - keman cover.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# Ay gız - keman cover.mp3 için sessizlik temizleniyor...
# Ay gız - keman cover.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_0.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_3.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_6.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_9.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_12.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_15.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_18.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_21.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_24.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_27.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_30.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_33.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_36.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_39.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_42.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_45.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_48.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_51.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_54.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_57.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_60.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_63.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_66.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_69.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_72.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_75.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_78.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_81.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_84.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_87.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_90.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_93.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_96.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_99.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_102.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_105.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_108.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_111.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_114.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_117.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_120.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_123.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_126.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_129.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_132.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_135.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_138.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_141.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_144.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_147.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_150.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_153.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_153_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_156.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_156_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_159.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_159_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_162.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_162_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_165.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_165_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_168.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_168_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_171.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_171_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_174.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_174_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_177.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_177_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_180.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_180_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_183.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_183_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_186.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_186_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_189.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_189_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_192.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_192_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_195.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_195_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarKeman\Ay gız - keman cover.mp3_segment_198.wav kaydedildi.
# mfcc_cikti_keman\Ay gız - keman cover.mp3_segment_198_mfcc.npy MFCC özellikleri kaydedildi.
# Ayrılık - Keman ( Violin ) Cover.mp3 için sessizlik temizleniyor...
# Ayrılık - Keman ( Violin ) Cover.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarKeman\Ayrılık - Keman ( Violin ) Cover.mp3_segment_0.wav kaydedildi.
# mfcc_cikti_keman\Ayrılık - Keman ( Violin ) Cover.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# ...
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_72.wav -> keman_2264.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_75.wav -> keman_2265.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_78.wav -> keman_2266.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_81.wav -> keman_2267.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_84.wav -> keman_2268.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_87.wav -> keman_2269.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_9.wav -> keman_2270.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_90.wav -> keman_2271.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_93.wav -> keman_2272.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_96.wav -> keman_2273.wav olarak yeniden adlandırıldı.
# Vazgeç Gönül - Zeynep Dizdar ｜ Keman.mp3_segment_99.wav -> keman_2274.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_0.wav -> keman_2275.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_102.wav -> keman_2276.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_105.wav -> keman_2277.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_108.wav -> keman_2278.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_111.wav -> keman_2279.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_114.wav -> keman_2280.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_117.wav -> keman_2281.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_12.wav -> keman_2282.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_120.wav -> keman_2283.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_123.wav -> keman_2284.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_126.wav -> keman_2285.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_129.wav -> keman_2286.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_132.wav -> keman_2287.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_135.wav -> keman_2288.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_138.wav -> keman_2289.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_141.wav -> keman_2290.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_15.wav -> keman_2291.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_18.wav -> keman_2292.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_21.wav -> keman_2293.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_24.wav -> keman_2294.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_27.wav -> keman_2295.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_3.wav -> keman_2296.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_30.wav -> keman_2297.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_33.wav -> keman_2298.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_36.wav -> keman_2299.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_39.wav -> keman_2300.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_42.wav -> keman_2301.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_45.wav -> keman_2302.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_48.wav -> keman_2303.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_51.wav -> keman_2304.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_54.wav -> keman_2305.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_57.wav -> keman_2306.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_6.wav -> keman_2307.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_60.wav -> keman_2308.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_63.wav -> keman_2309.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_66.wav -> keman_2310.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_69.wav -> keman_2311.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_72.wav -> keman_2312.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_75.wav -> keman_2313.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_78.wav -> keman_2314.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_81.wav -> keman_2315.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_84.wav -> keman_2316.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_87.wav -> keman_2317.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_9.wav -> keman_2318.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_90.wav -> keman_2319.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_93.wav -> keman_2320.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_96.wav -> keman_2321.wav olarak yeniden adlandırıldı.
# Yıldızların Altında - Keman ( Violin ) Cover.mp3_segment_99.wav -> keman_2322.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_0.wav -> keman_2323.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_12.wav -> keman_2324.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_15.wav -> keman_2325.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_18.wav -> keman_2326.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_21.wav -> keman_2327.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_24.wav -> keman_2328.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_27.wav -> keman_2329.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_3.wav -> keman_2330.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_30.wav -> keman_2331.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_33.wav -> keman_2332.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_36.wav -> keman_2333.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_39.wav -> keman_2334.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_42.wav -> keman_2335.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_45.wav -> keman_2336.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_48.wav -> keman_2337.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_51.wav -> keman_2338.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_54.wav -> keman_2339.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_57.wav -> keman_2340.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_6.wav -> keman_2341.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_60.wav -> keman_2342.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_63.wav -> keman_2343.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_66.wav -> keman_2344.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_69.wav -> keman_2345.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_72.wav -> keman_2346.wav olarak yeniden adlandırıldı.
# Çav Bella - Keman (Violin) Cover.mp3_segment_9.wav -> keman_2347.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_0.wav -> keman_2348.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_102.wav -> keman_2349.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_105.wav -> keman_2350.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_108.wav -> keman_2351.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_111.wav -> keman_2352.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_114.wav -> keman_2353.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_117.wav -> keman_2354.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_12.wav -> keman_2355.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_120.wav -> keman_2356.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_123.wav -> keman_2357.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_126.wav -> keman_2358.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_129.wav -> keman_2359.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_132.wav -> keman_2360.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_135.wav -> keman_2361.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_138.wav -> keman_2362.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_141.wav -> keman_2363.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_144.wav -> keman_2364.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_147.wav -> keman_2365.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_15.wav -> keman_2366.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_150.wav -> keman_2367.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_153.wav -> keman_2368.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_156.wav -> keman_2369.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_159.wav -> keman_2370.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_162.wav -> keman_2371.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_165.wav -> keman_2372.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_168.wav -> keman_2373.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_171.wav -> keman_2374.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_174.wav -> keman_2375.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_177.wav -> keman_2376.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_18.wav -> keman_2377.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_180.wav -> keman_2378.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_183.wav -> keman_2379.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_186.wav -> keman_2380.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_189.wav -> keman_2381.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_192.wav -> keman_2382.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_195.wav -> keman_2383.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_198.wav -> keman_2384.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_201.wav -> keman_2385.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_204.wav -> keman_2386.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_207.wav -> keman_2387.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_21.wav -> keman_2388.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_210.wav -> keman_2389.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_213.wav -> keman_2390.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_216.wav -> keman_2391.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_24.wav -> keman_2392.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_27.wav -> keman_2393.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_3.wav -> keman_2394.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_30.wav -> keman_2395.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_33.wav -> keman_2396.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_36.wav -> keman_2397.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_39.wav -> keman_2398.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_42.wav -> keman_2399.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_45.wav -> keman_2400.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_48.wav -> keman_2401.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_51.wav -> keman_2402.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_54.wav -> keman_2403.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_57.wav -> keman_2404.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_6.wav -> keman_2405.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_60.wav -> keman_2406.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_63.wav -> keman_2407.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_66.wav -> keman_2408.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_69.wav -> keman_2409.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_72.wav -> keman_2410.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_75.wav -> keman_2411.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_78.wav -> keman_2412.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_81.wav -> keman_2413.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_84.wav -> keman_2414.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_87.wav -> keman_2415.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_9.wav -> keman_2416.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_90.wav -> keman_2417.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_93.wav -> keman_2418.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_96.wav -> keman_2419.wav olarak yeniden adlandırıldı.
# İçimdeki Duman ｜ Keman Cover.mp3_segment_99.wav -> keman_2420.wav olarak yeniden adlandırıldı.
