# %%
import os
from pydub import AudioSegment, silence
import librosa
import numpy as np
import noisereduce as nr
import soundfile as sf

# Klasör yolları
input_folder = "gitar_sarkilari"  # İndirilen şarkılar burada
output_folder = "temizlenmis_parcalarGitar"  # Çıktılar buraya kaydedilecek
mfcc_folder = "mfcc_cikti"  # MFCC çıktılarını kaydedecek klasör

# Klasörleri oluştur (varsa hata vermez)
os.makedirs(output_folder, exist_ok=True)
os.makedirs(mfcc_folder, exist_ok=True)

# Sessizlik Temizleme Fonksiyonu
def remove_silence(audio_file, silence_thresh=-50, min_silence_len=500):
    """Verilen MP3 dosyasından sessiz bölümleri kaldırır."""
    audio = AudioSegment.from_mp3(audio_file)
    non_silent_chunks = silence.detect_nonsilent(audio, min_silence_len, silence_thresh)
    cleaned_audio = sum([audio[start:end] for start, end in non_silent_chunks])
    return cleaned_audio

# Gürültü Temizleme ve Normalizasyon Fonksiyonu
def process_audio(y, sr):
    # Gürültü Temizleme
    y_denoised = nr.reduce_noise(y=y, sr=sr)
    # Normalizasyon
    y_normalized = librosa.util.normalize(y_denoised)
    return y_normalized

# MFCC Çıkarma Fonksiyonu
def extract_mfcc(y, sr, n_mfcc=13):
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    return mfccs

# Şarkıları Parçalara Ayırma Fonksiyonu
def split_audio(audio, file_name, output_folder, segment_duration=3):
    """AudioSegment nesnesini segmentlere ayırır ve her segment için işlemler yapar."""
    total_duration = len(audio) / 1000  # milisaniyeden saniyeye

    for i in range(0, int(total_duration), segment_duration):
        segment = audio[i * 1000: (i + segment_duration) * 1000]
        
        # Segmenti geçici bir dosyaya kaydet
        segment_path = os.path.join(output_folder, f"{file_name}_segment_{i}.wav")
        segment.export(segment_path, format="wav")
        print(f"{segment_path} kaydedildi.")
        
        # Gürültü temizleme, normalizasyon ve MFCC çıkarma işlemleri
        y, sr = librosa.load(segment_path, sr=None)
        y_processed = process_audio(y, sr)
        mfcc_features = extract_mfcc(y_processed, sr)

        # MFCC sonuçlarını kaydet
        mfcc_file = os.path.join(mfcc_folder, f"{file_name}_segment_{i}_mfcc.npy")
        np.save(mfcc_file, mfcc_features)
        print(f"{mfcc_file} MFCC özellikleri kaydedildi.")

# Tüm şarkılar için işlemleri uygula
for file_name in os.listdir(input_folder):
    if file_name.endswith(".mp3"):
        file_path = os.path.join(input_folder, file_name)
        
        # Sessizliği Temizle
        print(f"{file_name} için sessizlik temizleniyor...")
        cleaned_audio = remove_silence(file_path)

        # Parçalara Ayır ve İşle
        print(f"{file_name} parçalara ayrılıyor ve işleniyor...")
        split_audio(cleaned_audio, file_name, output_folder, segment_duration=3)

print("Tüm şarkılar başarıyla işlendi.")
# Out:
# Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3 için sessizlik temizleniyor...
# Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_0.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_3.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_6.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_9.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_12.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_15.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_18.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_21.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_24.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_27.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_30.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_33.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_36.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_39.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_42.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_45.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_48.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_51.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_54.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_57.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_60.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_63.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_66.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_69.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_72.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_75.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_78.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_81.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_84.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_87.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_90.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_93.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_96.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_99.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_102.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_105.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_108.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_111.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_114.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_117.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_120.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_123.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_126.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_129.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_132.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_135.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_138.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_141.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_144.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_147.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_150.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_153.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_153_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_156.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_156_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_159.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_159_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_162.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_162_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_165.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_165_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_168.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_168_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_171.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_171_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_174.wav kaydedildi.
# mfcc_cikti\Akşam Güneşi - Orhan Gencebay ｜ Gitar Solo (Gitar Cover).mp3_segment_174_mfcc.npy MFCC özellikleri kaydedildi.
# ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3 için sessizlik temizleniyor...
# ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_0.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_3.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_6.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_9.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_12.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_15.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_18.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_21.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_24.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_27.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_30.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_33.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_36.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_39.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_42.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_45.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_48.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_51.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_54.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_57.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_60.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_63.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_66.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_69.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_72.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_75.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_78.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_81.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_84.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_87.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_90.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_93.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_96.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_99.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_102.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_105.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_108.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_111.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_114.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_117.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_120.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_123.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_126.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_129.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_132.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_135.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_138.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_141.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_144.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_147.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_150.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_153.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_153_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_156.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_156_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_159.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_159_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_162.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_162_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_165.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_165_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_168.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_168_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_171.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_171_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_174.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_174_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_177.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_177_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_180.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_180_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_183.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_183_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_186.wav kaydedildi.
# mfcc_cikti\ALİ AYŞEYİ SEVİYOR GİTAR SOLO TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_186_mfcc.npy MFCC özellikleri kaydedildi.
# ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3 için sessizlik temizleniyor...
# ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_0.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_3.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_6.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_9.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_12.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_15.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_18.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_21.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_24.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_27.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_30.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_33.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_36.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_39.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_42.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_45.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_48.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_51.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_54.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_57.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_60.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_63.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_66.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_69.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_72.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_75.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_78.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_81.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_84.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_87.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_90.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_93.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_96.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_99.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_102.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_105.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_108.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_111.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_114.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_117.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_120.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_123.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_126.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_129.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_132.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_135.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_138.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_141.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_144.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_147.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_150.wav kaydedildi.
# mfcc_cikti\ANLASANA GİTAR SOLO NOTA TAB(GİTAR DERSLERİ) TUTORİAL.mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3 için sessizlik temizleniyor...
# AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3 parçalara ayrılıyor ve işleniyor...
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_0.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_0_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_3.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_3_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_6.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_6_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_9.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_9_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_12.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_12_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_15.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_18.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_21.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_24.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_27.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_30.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_33.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_36.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_39.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_42.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_45.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_48.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_51.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_54.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_57.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_60.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_63.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_66.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_69.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_72.wav kaydedildi.
# mfcc_cikti\AYGIZ GİTAR SOLO  TAB NOTA (GİTAR DERSLERİ) TUTORİAL.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# ...
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_15_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_18.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_18_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_21.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_21_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_24.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_24_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_27.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_27_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_30.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_30_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_33.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_33_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_36.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_36_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_39.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_39_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_42.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_42_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_45.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_45_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_48.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_48_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_51.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_51_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_54.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_54_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_57.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_57_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_60.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_60_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_63.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_63_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_66.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_66_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_69.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_69_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_72.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_72_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_75.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_75_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_78.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_78_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_81.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_81_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_84.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_84_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_87.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_87_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_90.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_90_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_93.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_93_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_96.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_96_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_99.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_99_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_102.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_102_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_105.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_105_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_108.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_108_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_111.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_111_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_114.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_114_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_117.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_117_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_120.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_120_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_123.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_123_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_126.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_126_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_129.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_129_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_132.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_132_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_135.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_135_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_138.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_138_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_141.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_141_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_144.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_144_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_147.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_147_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_150.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_150_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_153.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_153_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_156.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_156_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_159.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_159_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_162.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_162_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_165.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_165_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_168.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_168_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_171.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_171_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_174.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_174_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_177.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_177_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_180.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_180_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_183.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_183_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_186.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_186_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_189.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_189_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_192.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_192_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_195.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_195_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_198.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_198_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_201.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_201_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_204.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_204_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_207.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_207_mfcc.npy MFCC özellikleri kaydedildi.
# temizlenmis_parcalarGitar\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_210.wav kaydedildi.
# mfcc_cikti\ÇEŞMİ SİYAHIM GİTAR SOLO NOTA TAB (GİTAR DERSLERİ) TUTORİAL.mp3_segment_210_mfcc.npy MFCC özellikleri kaydedildi.
# Tüm şarkılar başarıyla işlendi.

# %%
import os

# Keman ses dosyalarının bulunduğu klasör
gitar_klasoru = "temizlenmis_parcalarGitar"

# Eğer klasör varsa
if os.path.isdir(gitar_klasoru):
    for i, dosya in enumerate(os.listdir(gitar_klasoru)):
        if dosya.endswith(".mp3"):
            # Yeni dosya adını oluştur
            yeni_dosya_adi = f"gitar_{i + 1}.mp3"
            eski_dosya_yolu = os.path.join(gitar_klasoru, dosya)
            yeni_dosya_yolu = os.path.join(gitar_klasoru, yeni_dosya_adi)
            
            try:
                # Dosyayı yeniden adlandır
                os.rename(eski_dosya_yolu, yeni_dosya_yolu)
                print(f"{dosya} -> {yeni_dosya_adi} olarak yeniden adlandırıldı.")
            except Exception as e:
                print(f"Dosya adlandırılırken hata oluştu: {e}")
else:
    print("Belirtilen klasör bulunamadı.")
