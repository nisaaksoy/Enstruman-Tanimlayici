# %%
import yt_dlp
import os

# İndirme ve işleme yapılacak klasör
output_folder = "kanun_sarkilari"

# Klasörü oluştur (varsa hata vermez)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# YouTube playlist  tüm videoları indir ve ses dosyasını çıkartma
def download_playlist_audio(playlist_url, output_folder):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': os.path.join(output_folder, '%(title)s.%(ext)s'),
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        'noplaylist': False,  # Çalma listesi indirilmesini sağlamak için False olmalı
        'ignoreerrors': True,  # Hataları yok say ve devam et
    }

    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([playlist_url])
        print(f"Çalma listesi başarıyla indirildi ve {output_folder} klasörüne kaydedildi.")
    
    except Exception as e:
        print(f"Bir hata oluştu: {str(e)}")

# Örnek: YouTube playlist  URL'si
playlist_url = "https://www.youtube.com/playlist?list=PL3UTZuJF_rUrTAhQKXL2uAv-vWZyDpps7"  

# Playlist'teki tüm videoları indir ve MP3 formatında kaydetme
download_playlist_audio(playlist_url, output_folder)
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PL3UTZuJF_rUrTAhQKXL2uAv-vWZyDpps7
# [youtube:tab] PL3UTZuJF_rUrTAhQKXL2uAv-vWZyDpps7: Downloading webpage
# [youtube:tab] PL3UTZuJF_rUrTAhQKXL2uAv-vWZyDpps7: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: kanun
# [youtube:tab] PL3UTZuJF_rUrTAhQKXL2uAv-vWZyDpps7 page 1: Downloading API JSON
# [youtube:tab] Playlist kanun: Downloading 7 items of 7
# [download] Downloading item 1 of 7
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VS3LafxrMIs
# [youtube] VS3LafxrMIs: Downloading webpage
# [youtube] VS3LafxrMIs: Downloading ios player API JSON
# [youtube] VS3LafxrMIs: Downloading mweb player API JSON
# [youtube] VS3LafxrMIs: Downloading m3u8 information
# [info] VS3LafxrMIs: Downloading 1 format(s): 251
# [download] Destination: kanun_sarkilari\Aytaç Doğan - Kanun Resitali 1 (Full Albüm Video).webm
# [download] 100% of   53.22MiB in 00:00:15 at 3.50MiB/s
# ...
